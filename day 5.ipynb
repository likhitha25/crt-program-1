# %%
print("welcome")
# Out:
# welcome

# %%
x = 7676358756
print(x)
# Out:
# 7676358756

# %% [markdown]
# #python programming
# ##python programming
# ###python programming
# ####python programming
# #####python programming
# ######python programming
#
# 1.   python basic
# 2.   python advanced

# %% [markdown]
# ![image](data:image/jpeg;base64,...)

# %% [markdown]
# [click here](https://sites.google.com/view/gitam-221710405003/home)

# %%
print("Hello world")
# Out:
# Hello world

# %%
x = 10
y = 20
print(x + y)
print(x-y)
# Out:
# 30
# -10

# %%
x = int(input("enter x value"))
y = int(input("enter y value"))
print(x + y)
print(x - y)
# Out:
# enter x value123
# enter y value231
# 354
# -108

# %%
x = str(input("enter the name"))
y = int(input("my age is"))
print("my name is",  x , end='    ')
print("and my age is" , y)
# Out:
# enter the namerajesh
# my age is19
# my name is rajesh    and my age is 19

# %%
x = input("enter the name")
# Out:
# enter the namerajesh
# rajesh

# %%
a = 4
b = 5.898998
c = 5 + 6j
d = 8 + 9J
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'complex'>

# %%
c+d
# Out:
# (13+15j)

# %%
c*d
# Out:
# (-14+93j)

# %%
c - d
# Out:
# (-3-3j)

# %%
10 < 20
# Out:
# True

# %%
str1 = "gitam"
str2 = ' university'
str1 + str2
# Out:
# 'gitam university'

# %%
len(str1)
# Out:
# 5

# %%
len(str2)
# Out:
# 11

# %%
a = 423562473
len(str(a))
# Out:
# 9

# %% [markdown]
# ## operators

# %%
a = 20 
b = 30

# %%
a + b
# Out:
# 50

# %%
a - b
# Out:
# -10

# %%
a < b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a * b
# Out:
# 600

# %%
a / b
# Out:
# 0.6666666666666666

# %%
a % b
# Out:
# 20

# %%
23 ** 32
# Out:
# 37608910510519071039902074217516707306379521

# %%
i = int(input("enter i value"))
if i > 10 and i < 20:
  print("yes")
else:
  print("no")
# Out:
# enter i value134
# no

# %% [markdown]
# ##relational operators

# %%
a =100
b = 150

# %%
a < b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a <= b
# Out:
# True

# %%
a >= b
# Out:
# True

# %%
a != b
# Out:
# False

# %%
a = b

# %% [markdown]
# ##membership operators
#
#       1.in
#       2.not in

# %%
str1
# Out:
# 'gitam'

# %%
'z' in str1
# Out:
# False

# %%
'u' in str2
# Out:
# True

# %% [markdown]
# ##conditional operators
#
#
# 1.   if
# 2.   else
# 3.   elif

# %%
a = int(input("enter a value"))
if a % 2 == 0 :
  print(a,"is even ")
else :
   print(a,"is odd")
# Out:
# enter a value7
# 7 is odd
