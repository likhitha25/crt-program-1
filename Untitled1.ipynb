# %% [markdown]
# #tuples
#
#
# 1.   immutable

# %%
tuple1 = (10,20,30)

# %%
type(tuple1)
# Out:
# tuple

# %%
tuple1
# Out:
# (10, 20, 30)

# %%
tuple1.count(20)
# Out:
# 1

# %%
tuple1.index(20)
# Out:
# 1

# %% [markdown]
# #DICTIONARY{key1:value1,key2:value2}
#
#   1. KEYS SHOULD BE UNIQUE AND IMMUTABEL
#   2.

# %%
dict1={"name": "rajesh","age": "19", "address":"hstl"}
dict1['age']
# Out:
# '19'

# %%
dict1['course'] = "python"

# %%
dict1['course'] = "c"

# %%
dict1
# Out:
# {'address': 'hstl', 'age': '19', 'course': 'c', 'name': 'rajesh'}

# %%
del dict1["course"]

# %%
dict1
# Out:
# {'address': 'hstl', 'age': '19', 'name': 'rajesh'}

# %%
dict1.keys
# Out:
# <function dict.keys>

# %%
dict1.keys()
# Out:
# dict_keys(['name', 'age', 'address'])

# %%
dict1.values()
# Out:
# dict_values(['rajesh', '19', 'hstl'])

# %%
dict1.items()
# Out:
# dict_items([('name', 'rajesh'), ('age', '19'), ('address', 'hstl')])

# %%
print("name is", dict1['name'],"and age is ",dict1['age'],"my address is",dict1['address'] )
# Out:
# name is rajesh and age is  19 my address is hstl

# %%
for i in dict1.keys():
  print(i,"is",dict1[i])
# Out:
# name is rajesh
# age is 19
# address is hstl

# %%
chr(78)
# Out:
# 'N'
