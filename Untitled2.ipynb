# %% [markdown]
# ##Strings

# %%
str1 ='python programming12'

# %%
str1
# Out:
# 'python programming12'

# %%
len(str1)
# Out:
# 20

# %%
max(str1)
# Out:
# 'y'

# %%
min(str1)
# Out:
# ' '

# %%
str1.isalpha()
# Out:
# False

# %%
str2 = 'python'

# %%
str2.isalpha()
# Out:
# True

# %%
str2.isdigit()
# Out:
# False

# %%
str1.isdigit()
# Out:
# False

# %%
str1.isalnum()
# Out:
# False

# %%
str3 = 'python123'

# %%
str3.isalnum()
# Out:
# True

# %%
str3 = str3.lower()

# %%
str3
# Out:
# 'python123'

# %%
c = 0
str4="application1889"
b = list(str4)
b.sort()
for i in range():
   d = int(i)
   e = chr(d)
   c = c + e
   b.index(e) + 1
   print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-b8c56dafc3e7> in <module>()
#       7    d = int(i)
#       8    e = chr(d)
# ----> 9    c = c + e
#      10    b.index(e) + 1
#      11    print(c)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Out:
# ['1', '8', '8', '9', 'a', 'a', 'c', 'i', 'i', 'l', 'n', 'o', 'p', 'p', 't']

# %%
ord('9')
# Out:
# 57

# %%
chr(57)
# Out:
# '9'
